# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar los datos de los archivos de texto

#theta
pendulos_theta = np.loadtxt('PendulosTheta.txt')
cuna_theta = np.loadtxt('CunaNewtonTheta.txt')

#omega
pendulos_omega = np.loadtxt('PendulosOmega.txt')
cuna_omega = np.loadtxt('CunaNewtonOmega.txt')

#Tau
pendulos_alpha = np.loadtxt('PendulosAlpha.txt')
cuna_alpha = np.loadtxt('CunaNewtonAlpha.txt')

cuna_theta.shape, cuna_omega.shape, cuna_alpha.shape
# Out:
# (40,)

# %%
# Selecciona cada 4 elementos de un arreglo
# siendo la sintaxis [inicio:fin:paso]
# y se guarda en un nuevo arreglo

pendulos_theta = pendulos_theta[::4]
pendulos_omega = pendulos_omega[::4]
pendulos_alpha = pendulos_alpha[::4]

cuna_theta = cuna_theta[::4]
cuna_omega = cuna_omega[::4]
cuna_alpha = cuna_alpha[::4]


t=0
dt=1e0
tmax=10
time = np.arange(t,tmax,dt)

time.shape, cuna_alpha.shape
# Out:
# ((10,), (10,))

# %%
#@title Graficar de Theta

# Graficar los datos
plt.title('Theta vs Tiempo')
plt.plot(time, pendulos_theta,"-.r", label='Pendulo')
plt.plot(time, cuna_theta,"-.b", label='CunaNewton')
plt.xlabel('Tiempo')
plt.ylabel('Theta')
plt.legend()

# Realizar una estimación multilínea
# Aquí puedes agregar tu código para realizar la estimación multilínea

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 5
#       1 #@title Graficar de Theta
#       2
#       3 # Graficar los datos
#       4 plt.title('Theta vs Tiempo')
# ----> 5 plt.plot(time, pendulos_theta,"-.r", label='Pendulo')
#       6 plt.plot(time, cuna_theta,"-.b", label='CunaNewton')
#       7 plt.xlabel('Tiempo')
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (13,)

# %%
#@title Graficar de Omega

# Graficar los datos
plt.title('Omega vs Tiempo')
plt.plot(time, pendulos_omega,"-.r", label='Pendulo')
plt.plot(time, cuna_omega,"-.b", label='CunaNewton')
plt.xlabel('Tiempo')
plt.ylabel('Omega')
plt.legend()

# Realizar una estimación multilínea
# Aquí puedes agregar tu código para realizar la estimación multilínea

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 5
#       1 #@title Graficar de Omega
#       2
#       3 # Graficar los datos
#       4 plt.title('Omega vs Tiempo')
# ----> 5 plt.plot(time, pendulos_omega,"-.r", label='Pendulo')
#       6 plt.plot(time, cuna_omega,"-.b", label='CunaNewton')
#       7 plt.xlabel('Tiempo')
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\cterr\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (13,)

# %%
#@title Graficar de Tau

# Graficar los datos
plt.title('Alpha vs Tiempo')
plt.plot(time, pendulos_alpha,"-.r", label='Pendulos')
plt.plot(time, cuna_alpha,"-.b", label='CunaNewton')
plt.xlabel('Tiempo')
plt.ylabel('Alpha')
plt.legend()

# Realizar una estimación multilínea
# Aquí puedes agregar tu código para realizar la estimación multilínea

# Mostrar la gráfica
plt.show()
